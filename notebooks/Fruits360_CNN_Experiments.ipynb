# %% [markdown]
# # Fruits-360 CNN activation experiment
#
# Runnable wrapper for the reproducible experiment pipeline. **Scope: four-class fruit-type classification, not fresh/rotten classification.** The authoritative executable implementation is `experiments/run_fruits360_experiment.py`.

# %%
from pathlib import Path
import json, sys
ROOT = Path.cwd().resolve()
if ROOT.name == 'notebooks': ROOT = ROOT.parent
sys.path.insert(0, str(ROOT))
from experiments.run_fruits360_experiment import run
print(ROOT)

# %% [markdown]
# Run the next cell to download the official subset, hash-check splits, train all 12 configurations, select by validation macro F1, refit the winner, and evaluate official Test once.

# %%
summary = run()
summary['best_config'], summary['test_metrics']

# %%
from IPython.display import display, Image
display(Image(filename=str(ROOT / 'artifacts/experiment/validation_comparison.png')))
display(Image(filename=str(ROOT / 'artifacts/experiment/test_confusion_matrix.png')))

# %%
summary = json.loads((ROOT / 'artifacts/experiment/summary.json').read_text())
[{**{'activation': r['activation'], 'learning_rate': r['learning_rate']}, **r['validation_metrics']} for r in summary['experiments']]
